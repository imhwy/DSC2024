# %%
import os
from dotenv import load_dotenv
from llama_index.llms.openai import OpenAI
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.core import Settings


load_dotenv()

OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')
OPENAI_MODEL = os.getenv('OPENAI_MODEL')
OPENAI_EMBED_MODEL = os.getenv('OPENAI_EMBED_MODEL')
TEMPERATURE_MODEL = os.getenv('TEMPERATURE_MODEL')

# %%
llm = OpenAI(
    api_key=OPENAI_API_KEY,
    model=OPENAI_MODEL,
    temperature=TEMPERATURE_MODEL
)
embed_model = OpenAIEmbedding(
    api_key=OPENAI_API_KEY,
    model=OPENAI_EMBED_MODEL
)

# %%
Settings.llms = llm
Settings.embed_model = embed_model

# %%
from loaders import GeneralLoader

# %%
a = GeneralLoader()

# %%
documents = a.load_data(['https://tuyensinh.uit.edu.vn/trao-tri-qua-cong-nghe-so-i-he-thong-tra-cuu-mo-liet-si-cong-trinh-y-nghia-mua-he-xanh-uit-2024'])
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  2.85it/s]

# %%
documents
# Out:
# [Document(id_='https://tuyensinh.uit.edu.vn/trao-tri-qua-cong-nghe-so-i-he-thong-tra-cuu-mo-liet-si-cong-trinh-y-nghia-mua-he-xanh-uit-2024', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text=' T3, 30/07/2024 \\- 15:20\n\nNhân dịp kỷ niệm 77 năm ngày Thương binh, Liệt sĩ (27/7/1947 \\- 27/7/2024\\), các chiến sĩ Mùa Hè Xanh UIT đã phối hợp với Thành Đoàn, Hội Sinh viên Việt Nam Thành phố và Ban Chỉ huy Chiến dịch tình nguyện Mùa Hè Xanh TP. HCM để ra mắt công trình "Hệ thống tra cứu thông tin mộ liệt sĩ trên địa bàn TP. HCM"\xa0 \\-\xa0[https://www.anhhunglietsi.vn](https://www.anhhunglietsi.vn/?fbclid=IwZXh0bgNhZW0CMTAAAR3D_cDrliekwo7wYleeyT-RzIHfjVrbqSyS09mFNJjVlMCqUsHfpT0J5LE_aem_P9K8fJ7LnxOib41_BeYPMQ) tại Nghĩa trang Liệt sĩ Củ Chi. Đây là hoạt động thuộc khuôn khổ ngày hoạt động cao điểm "Chiến sĩ tình nguyện uống nước nhớ nguồn".\n\n\n\nCông trình "Hệ thống tra cứu thông tin mộ liệt sĩ trên địa bàn TP. Hồ Chí Minh" được thực hiện bởi đội hình chuyên cấp Thành, do chiến sĩ Mùa Hè Xanh thuộc đội hình Lập trình Web của Trường Đại học Công nghệ Thông tin, ĐHQG\\-HCM phụ trách, nhằm số hóa Nghĩa trang liệt sĩ Rừng Sác Cần Giờ. Công trình này giúp gia đình, người thân, và đồng đội của các anh hùng liệt sĩ tìm kiếm thông tin và vị trí bia mộ của liệt sĩ một cách nhanh chóng và dễ dàng. Hệ thống sử dụng thân thiện qua máy tra cứu hoặc thiết bị điện thoại di động có kết nối internet.\n\n\n![](/sites/default/files/uploads/images/202407/anh_2_10.jpg)\n\n\nNguyễn Thanh Bình (ngành An toàn Thông tin) và Lê Văn Anh Khoa (ngành Kỹ thuật Phần mềm) là hai sinh viên trực tiếp tham gia thiết lập và vận hành công trình này. Họ nhận thấy việc người dân tìm thông tin các liệt sĩ qua bản đồ tổng và liên hệ với các cán bộ khá bất tiện. Vì vậy, Bình và Khoa đã lên ý tưởng tạo ra một trang web có chức năng bản đồ, cho phép người dùng tương tác và xem thông tin các ngôi mộ tại một địa điểm cụ thể trên bản đồ. Đồng thời, các cán bộ cũng có thể đăng nhập vào trang quản lý để thêm thông tin của các liệt sĩ.  \n\n\xa0\n\n\nThời gian nhận, cho ra sản phẩm, chỉnh sửa và hoàn thiện hệ thống chỉ trong vòng 3 tuần, nên Bình và Khoa gặp ít khó khăn trong việc thu thập thông tin dữ liệu của các liệt sĩ. Ngoài ra, việc liên hệ các cơ quan nhà nước để thu thập dữ liệu quan trọng cũng diễn ra suôn sẻ. Các khâu chuyên môn khác không gặp nhiều khó khăn do cả Bình và Khoa đều là những sinh viên công nghệ thông tin.\n\n\n![](/sites/default/files/uploads/images/202407/anh_1_8.jpg)\n\n\n***Nguyễn Thanh Bình (ngành An toàn Thông tin) và Lê Văn Anh Khoa (ngành Kỹ thuật Phần mềm)***\n\n\nHệ thống tra cứu ra mắt thành công cũng là niềm vinh dự đối với Bình và Khoa khi có cơ hội thực hiện dự án ý nghĩa này. Bình chia sẻ: “Đây không chỉ là một cơ hội để bản thân rèn luyện mà còn là niềm tự hào khi được góp sức cho đất nước.” Khoa cũng bộc bạch: “Đây vừa là một trải nghiệm giúp phát triển kỹ năng lập trình, vừa có thể đóng góp cho đất nước trong việc gìn giữ nét đẹp biết ơn công lao của các chiến sĩ đã hy sinh.”\n\n\n![](/sites/default/files/uploads/images/202407/anh_3_3.jpg)\n\n\nLương Võ Phương Dung, Đội trưởng đội hình Lập trình Web Mùa Hè Xanh UIT 2024, đánh giá cao những nỗ lực của các chiến sĩ trong quá trình hoàn thiện hệ thống. Phương Dung nhận xét: “Công trình đã giúp thân nhân của các anh hùng liệt sĩ tìm được nơi an nghỉ của họ và lan tỏa cho các bạn sinh viên biết thêm về những anh hùng đã hy sinh cho đất nước. Trường Đại học Công nghệ Thông tin đã hỗ trợ Trong tương lai, Bình và Khoa sẽ tiếp tục giai đoạn 3 của dự án, hy vọng số hóa hết các nghĩa trang liệt sĩ của thành phố và các tỉnh thành trên cả nước.\n\n\nNgọc Lân\n\n\n ', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n')]

# %%
import weaviate
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
from llama_index.vector_stores.weaviate import WeaviateVectorStore
from llama_index.core.response.notebook_utils import display_response
from llama_index.core import StorageContext
from llama_index.core.storage.docstore import SimpleDocumentStore
from llama_index.core import Sente
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 7
#       5 from llama_index.core import StorageContext
#       6 from llama_index.core.storage.docstore import SimpleDocumentStore
# ----> 7 from llama_index.core import Sente
#
# ImportError: cannot import name 'Sente' from 'llama_index.core' (c:\Users\Admin\anaconda3\envs\RAG-chatbot\lib\site-packages\llama_index\core\__init__.py)

# %%
client = weaviate.connect_to_local()

# %%
client.collections.delete("DSC2024")

# %%
documents = a.load_data(['D:/UIT/DSC-2024/DSC2024/notebook/CV_Fullstack_Developer_TranTuanKiet_d3cddc.pdf'])
# Out:
# 100%|██████████| 1/1 [00:33<00:00, 33.98s/it]

# %%
from llama_index.storage.docstore.mongodb import MongoDocumentStore

# %%
vector_store = WeaviateVectorStore(weaviate_client=client, index_name='DSC2024')
storage_context = StorageContext.from_defaults(docstore=MongoDocumentStore.from_uri('mongodb://localhost:27017', db_name='QAsystem'),vector_store=vector_store)
index = VectorStoreIndex.from_documents(
                documents=documents,
                storage_context=storage_context
)

# %%
vector_store = WeaviateVectorStore(weaviate_client=client, index_name='DSC2024')
storage_context = StorageContext.from_defaults(docstore=MongoDocumentStore.from_uri('mongodb://localhost:27017', db_name='QAsystem'),vector_store=vector_store)
index = VectorStoreIndex.from_vector_store(
                vector_store=vector_store,
                storage_context=storage_context
            )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 vector_store = WeaviateVectorStore(weaviate_client=client, index_name='DSC2024')
#       2 storage_context = StorageContext.from_defaults(docstore=MongoDocumentStore.from_uri('mongodb://localhost:27017', db_name='QAsystem'),vector_store=vector_store)
#       3 index = VectorStoreIndex.from_vector_store(
#       4                 vector_store=vector_store,
#       5                 storage_context=storage_context
#       6             )
#
# NameError: name 'WeaviateVectorStore' is not defined

# %%
query_engine = index.as_query_engine(similarity_top_k=2)
response = query_engine.query("Tên tác giả của cv là gì?")

# %%
response
# Out:
# Response(response='Tên tác giả của CV là Tran Tuan Kiet.', source_nodes=[NodeWithScore(node=TextNode(id_='9c4aecfb-d660-4e4d-a1f3-7af5235a9f5c', embedding=[-0.025196988135576248, -0.003818774363026023, 0.0004218246031086892, -0.015217412263154984, 0.0541781410574913, -0.06031586974859238, 0.005843532271683216, 0.05953134596347809, -0.017420995980501175, -0.03470354527235031, -0.012875384651124477, 0.001749310176819563, -0.05431658774614334, -0.008716265670955181, 0.01659032516181469, 0.04224879667162895, -0.051963020116090775, -0.05990053340792656, -0.016371119767427444, -0.04624062776565552, 0.01767481118440628, -0.014732854440808296, 0.021816624328494072, 0.014594409614801407, 0.03461124747991562, -0.027065996080636978, -0.024550912901759148, 0.03571880981326103, -0.0312654934823513, -0.011323646642267704, 0.009812288917601109, -0.034380506724119186, 0.03211923688650131, 0.0028669650200754404, 0.049101825803518295, 0.03604184836149216, 0.039018414914608, 0.003608222585171461, 0.016913363710045815, -0.008081726729869843, -0.009068147279322147, -0.03668792173266411, 0.017905551940202713, -0.0035245788749307394, -0.008502829819917679, 0.009218129329383373, -0.05173227936029434, 0.02909652329981327, 7.530650327680632e-05, 0.010239160619676113, 0.012344678863883018, -0.036595627665519714, -0.003789931768551469, 0.06594596803188324, -0.01943998411297798, -0.04757893085479736, 0.007643317338079214, 0.04559455066919327, -0.020247580483555794, 0.04144120216369629, 0.03622644022107124, -0.008739340119063854, 0.018643924966454506, 0.03168082982301712, -0.030688639730215073, 0.01889774203300476, -0.019024649634957314, -0.031080901622772217, -0.02015528455376625, -0.00492921844124794, -0.030780937522649765, 0.024527838453650475, -0.004
Docker, quen thuộc với phát triển theo phong cách Agile sử dụng Jira.\n\n# DỰ ÁN\n\n# Sobee - Dự án nhóm (Kích thước nhóm: 2) - Tháng 2 năm 2024 - Tháng 6 năm 2024\n\n- Phát triển một nền tảng thương mại điện tử toàn diện giúp trải nghiệm mua sắm mượt mà trên web và di động.\n- Phát triển và duy trì ứng dụng di động đa nền tảng bằng React Native.\n- Xây dựng giao diện web đáp ứng với Next.js và TypeScript.\n- Triển khai các API backend với Express.js để xử lý các chức năng thương mại điện tử.\n- Hợp tác với đồng đội để cung cấp các giải pháp phần mềm chất lượng cao.\n- Github: https://github.com/orgs/Sobee-Project/repositories\n\n# Chatbot - Dự án nhóm (Kích thước nhóm: 3) - Tháng 7 năm 2023 - Tháng 9 năm 2023\n\n- Nỗ lực giúp người dùng trò chuyện với bot được tạo bằng trí tuệ nhân tạo (Mô hình Ngôn ngữ Lớn) từ nhóm AI.\n- Chatbot giúp người dùng có thể nhận thông tin hơn về các dịch vụ công cộng của chính phủ và cung cấp hướng dẫn từng bước dựa trên câu hỏi của người dùng.\n- Thiết kế, lập trình giao diện người dùng để tương tác với Chatbot AI bằng Figma và React Native.\n- Viết API để lưu dữ liệu người dùng như: phòng chat, tin nhắn, tin nhắn đã lưu... sử dụng ExpressJS và MongoDB.\n- Github Ứng dụng: https://github.com/tuankietcoderr/chatbot_rn\n- Github API: https://github.com/tuankietcoderr/chatbot_server\n\n# E-Tour - Dự án nhóm (Kích thước nhóm: 3) - Tháng 3 năm 2023 - Tháng 7 năm 2023\n\n- Nỗ lực giúp các công ty du lịch tải lên tour của họ và kết nối với người dùng là những người du lịch dễ dàng và thuận tiện hơn để tìm và đặt vé.\n- Là một nhà phát triển frontend để xây dựng các màn hình di động từ thiết kế bằng React Native với Typescript.\n- Github: https://github.com/tuankietcoderr/e-tour-rn\n\n# SoWaste - Dự án nhóm (Kích thước nhóm: 4) - Tháng 1 năm 2023 - Tháng 4 năm 2023\n\n- Nỗ lực giúp người dùng phân loại chất thải nhanh chóng và chính xác.\n- Không chỉ là một nhà phát triển frontend để xây dựng các màn hình di động từ thiết kế mà còn là nhà phát triển backend để quản lý cơ sở dữ liệu và triển khai ứng dụng.\n- Viết API để quản lý dữ liệu ứng dụng tốt hơn và lưu dữ liệu người dùng như yêu thích, quà tặng đã lưu, quà tặng đã mua... sử dụng Golang, Gin framework, Xác thực Google, Firebase.\n- Github: https://github.com/GDSC-UIT/SoWaste/\n\nLiên hệ: Tran Tuan Kiet | +84348071412', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n')

# %%
print(a.id_)
# Out:
# 1ce916a8-4473-4de6-9984-cad8542cb658

# %%
len(storage_context.docstore.docs)
# Out:
# 0

# %%
index.delete_nodes(['1a955af0-9bdf-4e45-a9f7-3d9d57cdca2e','f8da2343-9cf5-4823-b4ec-529e33d4e632'], delete_from_docstore=True)

# %%
index = VectorStoreIndex.from_vector_store(
                vector_store=vector_store,
                storage_context=storage_context
            )
